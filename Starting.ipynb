# %%
from google.colab import userdata
import os

# Lấy token từ Secret của Colab
token = userdata.get('MY_GITHUB_TOKEN')
username = "haunk"
repo = "SMU_MITB_NLP"

# Cấu hình Git Remote
# !git remote remove origin
# !git remote add origin https://{token}@github.com/{username}/{repo}.git

print("Đã kết nối thành công với GitHub!")
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# Đã kết nối thành công với GitHub!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/SMU_MITB_NLP
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/SMU_MITB_NLP

# %%
# 1. Initialize the local folder as a Git repository
# !git init

# 2. Create a .gitignore file to exclude Drive junk files
with open(".gitignore", "w") as f:
    f.write(".ipynb_checkpoints/\n")
    f.write("__pycache__/\n")
    f.write("*.pyc\n")
    f.write(".DS_Store\n") # Exclude Mac junk files if any

# 3. Configure your Git identity (required for committing)
# !git config --global user.email "haukimng@example.com"
# !git config --global user.name "haunk"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/SMU_MITB_NLP/.git/

# %%
from google.colab import userdata

# Fetch the token securely from Colab Secrets
token = userdata.get('MY_GITHUB_TOKEN')
username = "haunk"
repo = "SMU_MITB_NLP"

# Safely remove existing remote if any, then add the authenticated one
# !git remote remove origin
# !git remote add origin https://{token}@github.com/{username}/{repo}.git

# Set the default branch name to 'main'
# !git branch -M main

print("Successfully linked Google Drive folder to GitHub remote!")
# Out:
# error: No such remote: 'origin'
# Successfully linked Google Drive folder to GitHub remote!

# %%
# 1. Stage all files in the current folder
# !git add .

# 2. Create your first save point (commit)
# !git commit -m "Initial commit: Add all lab folders from Google Drive"

# 3. Push the files to GitHub
# !git push -u origin main
# Out:
# [main (root-commit) 70a3e69] Initial commit: Add all lab folders from Google Drive
#  16 files changed, 10358 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 lab0/hello_world.py
#  create mode 100644 lab0/python_intro.ipynb
#  create mode 100644 lab1/lab1_Nguyen Kim Hau.ipynb
#  create mode 100644 lab1/our_model.tar
#  create mode 100644 lab1/pytorch_intro_lab.ipynb
#  create mode 100644 lab2/Word2vec_lab.ipynb
#  create mode 100644 lab2/lab2_Nguyen Kim Hau.ipynb
#  create mode 100644 lab2/proc.dat
#  create mode 100644 lab2/text8.zip
#  create mode 100644 lab3/Nguyen Kim Hau_lab3.ipynb
#  create mode 100644 lab3/RNNLM_lab.ipynb
#  create mode 100644 lab3/lm.bin
#  create mode 100644 lab3/proc.dat
#  create mode 100644 lab3/the_adventures_of_tom_sawyer.txt
# Enumerating objects: 22, done.
# Counting objects: 100% (22/22), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (20/20), done.
# ...
