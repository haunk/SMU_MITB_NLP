# %%
# All steps to git pull

from google.colab import userdata

token = userdata.get('MY_GITHUB_TOKEN')
username = "haunk"
repo = "SMU_MITB_NLP"

# Kết nối Remote bảo mật
# !git remote remove origin
# !git remote add origin https://{token}@github.com/{username}/{repo}.git

# Lấy code mới nhất từ nhánh main về
# !git pull origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# All steps to git push

message ="Update"

from google.colab import userdata

# Fetch the token securely from Colab Secrets
token = userdata.get('MY_GITHUB_TOKEN')
username = "haunk"
repo = "SMU_MITB_NLP"

# Cấu hình danh tính để Git không bắt lỗi (Chỉ cần chạy, không lo bị lộ thông tin)
# !git config --global user.email "haukimng@gmail.com"
# !git config --global user.name "haunk"

# Safely remove existing remote if any, then add the authenticated one
# !git remote remove origin
# !git remote add origin https://{token}@github.com/{username}/{repo}.git

# !git add .
# !git commit -m "{message}"
# !git push -u origin main

# %%
from google.colab import userdata

token = userdata.get('MY_GITHUB_TOKEN')
username = "haunk"
repo = "SMU_MITB_NLP"

# Step 1: Clone (need to do this every new session)
# !git clone https://{token}@github.com/{username}/{repo}.git

# Step 2: Move into the repo folder
# %cd {repo}

# Now you can pull, push, etc.
# !git pull origin main
# Out:
# Cloning into 'SMU_MITB_NLP'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 36 (delta 0), reused 3 (delta 0), pack-reused 32 (from 1)
# Receiving objects: 100% (36/36), 63.68 MiB | 26.58 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/SMU_MITB_NLP
# From https://github.com/haunk/SMU_MITB_NLP
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# All steps to git push

message ="Lab5"

from google.colab import userdata

# Fetch the token securely from Colab Secrets
token = userdata.get('MY_GITHUB_TOKEN')
username = "haunk"
repo = "SMU_MITB_NLP"

# Cấu hình danh tính để Git không bắt lỗi (Chỉ cần chạy, không lo bị lộ thông tin)
# !git config --global user.email "haukimng@gmail.com"
# !git config --global user.name "haunk"

# Safely remove existing remote if any, then add the authenticated one
# !git remote remove origin
# !git remote add origin https://{token}@github.com/{username}/{repo}.git

# !git add .
# !git commit -m "{message}"
# !git push -u origin main
# Out:
# On branch main
# nothing to commit, working tree clean
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date
